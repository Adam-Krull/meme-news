# %% [markdown]
# # Purpose
#
# As the filename implies, the purpose of this notebook is to see if I can capture the links to the full articles from the News API. The links to the articles will be included in the tweet body so people can view the full article if they please.

# %%
import re
import requests

from env import API_KEY

# %% [markdown]
# I'll make a request of the news API and see if I get a good response.

# %%
url = f"https://newsapi.org/v2/top-headlines?country=us&apiKey={API_KEY}"

response = requests.get(url)

response
# Out:
# <Response [200]>

# %% [markdown]
# Looks good! Let's see what's inside the JSON object.

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 35,
#  'articles': [{'source': {'id': 'politico', 'name': 'Politico'},
#    'author': None,
#    'title': 'US declines to rule out hitting targets in Iran, Jake Sullivan says - POLITICO',
#    'description': 'He said that American military action in the region will continue.',
#    'url': 'https://www.politico.com/news/2024/02/04/us-strikes-iran-jake-sullivan-00139490',
#    'urlToImage': 'https://static.politico.com/9d/49/57de150f49e0ba328c0e20d028cf/iraq-us-airstrikes-91401.jpg',
#    'publishedAt': '2024-02-04T20:20:16Z',
#    'content': 'When asked by Fox News Sunday host Shannon Bream if strikes within Iran are on or off the table, National Security Council spokesperson John Kirby said that what you saw on Friday night was just the … [+2367 chars]'},
#   {'source': {'id': 'the-wall-street-journal',
#     'name': 'The Wall Street Journal'},
#    'author': 'Joseph De Avila',
#    'title': "Facebook Turns 20: From Mark Zuckerberg's Harvard Dorm Room to the Metaverse - The Wall Street Journal",
#    'description': 'The college startup grew to one of the world’s largest companies',
#    'url': 'https://www.wsj.com/tech/facebook-turns-20-from-mark-zuckerbergs-harvard-dorm-room-to-the-metaverse-817a73da',
#    'urlToImage': 'https://images.wsj.net/im-920511/social',
#    'publishedAt': '2024-02-04T19:09:00Z',
#    'content': 'Facebook, the brainchild of \r\nMark Zuckerberg, turns 20 years old on Sunday.\xa0Zuckerberg, now 39, launched the site with three others out of his dorm room at Harvard University, aiming to create a dig… [+272 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'Sarah Al-Arshani',
#    'title': 'South Dakota tribe banned Gov. Noem from reservation over comments on U.S.-Mexico border - USA TODAY',
#    'description': 'In a statement, Oglala Sioux Trib President Frank Star Comes Out banned South Dakota Republican Gov. Kristi Noem from the Pine Ridge Reservation.',
#    'url': 'https://www.usatoday.com/story/news/politics/2024/02/04/gov-noem-banned-from-south-dakota-reservation-following-border-remarks/72472410007/',
#    'urlToImage': 'https://www.usatoday.com/gcdn/authoring/authoring-images/2024/02/04/USAT/72472960007-ap-tribe-bans-governor-south-dakota.jpg?crop=4607,2593,x0,y239&width=3200&height=1802&format=pjpg&auto=webp',
#    'publishedAt': '2024-02-04T18:33:41Z',
#    'content': 'A South Dakota tribe has banned Republican Gov. Kristi Noem from the Pine Ridge Reservation\xa0following her remarks on deterring immigration at the U.S.-Mexico border.\r\nDue to the safety of the Oyate, … [+1918 chars]'},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': 'the-hill', 'name': 'The Hill'},
#    'author': 'Miranda Nazzaro',
#    'title': 'Former Trump official dies after being shot in DC carjacking spree - The Hill',
#    'description': 'A former Trump administration official has died after being shot in an attempted carjacking spree in downtown Washington, D.C., last Monday, the victim’s family confirmed to The Hill. “It is with profound sadness that I wish to inform the community of the pas…',
#    'url': 'https://thehill.com/homenews/state-watch/4447433-former-trump-official-dies-after-being-shot-in-dc-carjacking-spree/',
#    'urlToImage': 'https://thehill.com/wp-content/uploads/sites/2/2023/08/Police-Lights-1.png?w=1280',
#    'publishedAt': '2024-02-04T18:14:00Z',
#    'content': 'Skip to content\r\nA former Trump administration official has died after being shot in an attempted carjacking spree in downtown Washington, D.C., last Monday, the victim’s family confirmed to The Hill… [+3151 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "Hage Geingob death: Namibia's new President Mbumba sworn-in hours after predecessor dies - BBC.com",
#    'description': 'Namibia sees a smooth transition of power following the death in office of Hage Geingob at 82.',
#    'url': 'https://www.bbc.com/news/world-africa-68196412',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/9DAC/production/_132546304_c4def4ea1c254e676b6430fb1b4d7809779cbbd20_315_5500_30961000x563.jpg',
#    'publishedAt': '2024-02-04T17:59:00Z',
#    'content': 'By Wycliffe Muia &amp; Damian ZaneBBC News\r\nPresident Nangolo Mbumba took the oath of office hours after announcing the death of his predecessor\r\nNamibia has a new president in the shape of Nangolo M… [+4181 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Tina Burnside, Nouran Salahieh',
#    'title': 'An intense atmospheric river moves into California, threatening to flood roads and trigger mudslides - CNN',
#    'description': 'An intense, long-lasting atmospheric river is moving into California, bringing the potential for “life-threatening” flooding, mud slides and widespread power outages as it dumps heavy rain and snow. Here’s the latest:',
#    'url': 'https://www.cnn.com/2024/02/04/us/california-atmospheric-river-flooding/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-1976110646.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2024-02-04T17:35:00Z',
#    'content': 'An intense, long-lasting atmospheric river is moving into California Sunday, bringing the potential for life-threatening flooding, mudslides and widespread power outages as it dumps heavy rain and sn… [+5033 chars]'},
#   {'source': {'id': None, 'name': 'The Times of Israel'},
#    'author': 'The Times of Israel',
#    'title': 'After Ben Gvir pans Biden, Netanyahu lauds White House support during war - The Times of Israel',
#    'description': None,
#    'url': 'https://www.timesofisrael.com/after-ben-gvir-pans-biden-netanyahu-lauds-white-house-support-during-war/',
#    'urlToImage': None,
#    'publishedAt': '2024-02-04T17:08:36Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'FRANCE 24 English'},
#    'author': 'Sophian Aubin',
#    'title': 'Air pollution a factor in spiking cancer cases, report says - FRANCE 24 English',
#    'description': 'New estimates from the World Health Organization (WHO) predict a 77% increase in cancer cases globally by 2050. The report points to air pollution as one of the factors driving the expected increase in cancer rates, even though it does not have the same effec…',
#    'url': 'https://www.france24.com/en/environment/20240204-air-pollution-factor-spiking-cancer-cases-who-says',
#    'urlToImage': 'https://s.france24.com/media/display/b46faa12-c370-11ee-9792-005056bf30b7/w:1280/p:16x9/dddd-4.jpg',
#    'publishedAt': '2024-02-04T17:07:26Z',
#    'content': 'New estimates from the World Health Organization (WHO) predict a 77% increase in cancer cases globally by 2050. The report points to air pollution as one of the factors driving the expected increase … [+6312 chars]'},
#   {'source': {'id': None, 'name': 'Deadline'},
#    'author': 'Bruce Haring',
#    'title': '‘SNL’: Ayo Edebiri Seemingly Addresses Her Controversial Comments About Jennifer Lopez: ‘It’s Wrong to Run Your Mouth on a Podcast’ - Deadline',
#    'description': 'Saturday Night Live host Ayo Edebiri probably wished that she could take back some mean comments made during a podcast about this week’s musical guest, Jennifer Lopez. Fortunately (and perhap…',
#    'url': 'http://deadline.com/2024/02/snl-ayo-edebiri-seemingly-addresses-controversial-comments-about-jennifer-lopez-1235813828/',
#    'urlToImage': 'https://deadline.com/wp-content/uploads/2024/01/Ayo-Edebiri-Jennifer-Lopez.jpg?w=1024',
#    'publishedAt': '2024-02-04T16:50:00Z',
#    'content': 'Saturday Night Live host Ayo Edebiri probably wished that she could take back some mean comments made during a podcast about this week’s musical guest, Jennifer Lopez.\r\nFortunately (and perhaps awkwa… [+1335 chars]'},
#   {'source': {'id': None, 'name': 'Florida Today'},
#    'author': 'Rick Neale',
#    'title': 'Will rain, wind scuttle NASA PACE spacecraft launch Tuesday morning? - Florida Today',
#    'description': 'NASA crews are targeting 1:33 a.m. EST Tuesday to launch the PACE observatory atop a SpaceX Falcon 9 rocket from Launch Complex 40.',
#    'url': 'https://www.floridatoday.com/story/tech/science/space/2024/02/03/will-rain-wind-scuttle-nasa-pace-spacecraft-launch-tuesday-morning-at-cape-canaveral-florida/72449585007/',
#    'urlToImage': 'https://www.floridatoday.com/gcdn/presto/2020/02/05/PBRE/3d4c2618-f6eb-4edf-84d2-36f38d352a12-PACE.jpg?crop=1019,574,x4,y0&width=1019&height=574&format=pjpg&auto=webp',
#    'publishedAt': '2024-02-04T16:27:47Z',
#    'content': "Will windy, rainy environmental conditions scrub NASA's PACE environmental-science spacecraft launch attempt early Tuesday morning from Cape Canaveral Space Force Station?\r\nKeep a keen eye on the wea… [+1702 chars]"},
#   {'source': {'id': 'fox-news', 'name': 'Fox News'},
#    'author': 'Anders Hagstrom',
#    'title': 'Trump reveals criteria for running mate, name drops two top Republicans - Fox News',
#    'description': 'Former President Trump discussed what he looks for in a potential vice president, mentioning two notable Republicans as possible contenders.',
#    'url': 'https://www.foxnews.com/politics/trump-reveals-criteria-running-mate-name-drops-two-top-republicans',
#    'urlToImage': 'https://static.foxnews.com/foxnews.com/content/uploads/2022/08/ebcd6235-GettyImages-1413333546.jpg',
#    'publishedAt': '2024-02-04T16:06:06Z',
#    'content': 'Join Fox News for access to this content\r\nPlus get unlimited access to thousands of articles, videos and more with your free account!\r\nPlease enter a valid email address.\r\nBy entering your email, you… [+2165 chars]'},
#   {'source': {'id': None, 'name': 'Www.cnn.co'},
#    'author': 'CNN',
#    'title': "Where to watch 2024's solar eclipse - CNN",
#    'description': 'Enter your address to find out what you can expect to see in a city near you.',
#    'url': 'https://www.cnn.co/interactive/2024/02/world/solar-eclipse-2024-map-dg-scn/',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/240126131456-solar-eclipse-oregon-2017-file.jpg?c=original',
#    'publishedAt': '2024-02-04T16:04:22Z',
#    'content': 'One of the years most anticipated celestial events a total solar eclipse will put on a dramatic show April 8 as it crosses over Mexico, the United States and Canada.\r\nA total solar eclipse occurs whe… [+1370 chars]'},
#   {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#    'author': 'Tyler Conway',
#    'title': 'The Rock Thanks Cody Rhodes amid Rumors, Backlash to Roman Reigns WrestleMania Tease - Bleacher Report',
#    'description': "Either The Rock has not heard the backlash surrounding his appearance on SmackDown or he's choosing to ignore it. The Rock took to social media Sunday to…",
#    'url': 'https://bleacherreport.com/articles/10107920-the-rock-thanks-cody-rhodes-amid-rumors-backlash-to-roman-reigns-wrestlemania-tease',
#    'urlToImage': 'https://media.bleacherreport.com/image/upload/x_0,y_636,w_1799,h_1201,c_crop/c_fill,g_faces,w_3800,h_2000,q_95/v1707059223/bhjfnpl38o1c5ydlckej.jpg',
#    'publishedAt': '2024-02-04T15:46:28Z',
#    'content': "Michelle Farsi/Zuffa LLC\r\nEither The Rock has not heard the backlash surrounding his appearance on SmackDown or he's choosing to ignore it.\r\nThe Rock took to social media Sunday to thank WWE fans and… [+4329 chars]"},
#   {'source': {'id': None, 'name': 'New York Post'},
#    'author': 'Dan Martin',
#    'title': 'Bill Belichick thanks Patriots fans with full-page Boston Globe ad - New York Post ',
#    'description': 'The longtime Patriots coach, who mutually parted ways with the team last month, thanked fans for their passion and loyalty.',
#    'url': 'https://nypost.com/2024/02/04/sports/bill-belichick-thanks-patriots-fans-with-full-page-boston-globe-ad/',
#    'urlToImage': 'https://nypost.com/wp-content/uploads/sites/2/2024/02/belichick-letter.jpg?quality=75&strip=all&1707042682&w=1024',
#    'publishedAt': '2024-02-04T15:42:00Z',
#    'content': 'Bill Belichick said farewell to New England Patriots fans with a full-page ad on page A3 in The Boston Globe on Sunday.\r\nThe longtime Patriots coach, who mutually parted ways with the team last month… [+1833 chars]'},
#   {'source': {'id': 'bleacher-report', 'name': 'Bleacher Report'},
#    'author': 'Joseph Zucker',
#    'title': "Lakers Rumors: LAL 'Have Not Reacted to' LeBron James' 'Maneuvers' About Trade Help - Bleacher Report",
#    'description': "The Los Angeles Lakers haven't yet deviated from their original NBA trade deadline plans despite star LeBron James indirectly applying some pressure to the…",
#    'url': 'https://bleacherreport.com/articles/10107914-lakers-rumors-lal-have-not-reacted-to-lebron-james-maneuvers-about-trade-help',
#    'urlToImage': 'https://media.bleacherreport.com/image/upload/x_102,y_134,w_1590,h_1057,c_crop/c_fill,g_faces,w_3800,h_2000,q_95/v1707057295/lfyptjvmeko1x9qr4tir.jpg',
#    'publishedAt': '2024-02-04T15:33:45Z',
#    'content': "Nathaniel S. Butler/NBAE via Getty Images\r\nThe Los Angeles Lakers haven't yet deviated from their original NBA trade deadline plans despite star LeBron James indirectly applying some pressure to the … [+3140 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'MEGAN JANETSKY, MARCOS ALEMÁN',
#    'title': 'El Salvador election: Salvadorans head to vote as Bukele eyes second term - The Associated Press',
#    'description': 'Salvadorans are voting in presidential and legislative elections that are largely about the tradeoff between security and democracy. With soaring approval ratings and virtually no competition, Nayib Bukele was almost certainly headed for a second term as pres…',
#    'url': 'https://apnews.com/article/el-salvador-election-bukele-gang-violence-democracy-dc9f65f450875c5841f937753cd3101a',
#    'urlToImage': 'https://dims.apnews.com/dims4/default/520ebd0/2147483647/strip/true/crop/5629x3166+0+293/resize/1440x810!/quality/90/?url=https%3A%2F%2Fassets.apnews.com%2F63%2F5b%2F5d40e94ccbefff340adecf290482%2Fe1defa9a8e7a4174aada06db1b052bfd',
#    'publishedAt': '2024-02-04T15:24:00Z',
#    'content': 'MEJICANOS, El Salvador (AP) Salvadorans were voting Sunday in presidential and legislative elections with many expressing willingness to forego some elements of democracy if it means keeping gang vio… [+5748 chars]'},
#   {'source': {'id': 'axios', 'name': 'Axios'},
#    'author': 'Axios',
#    'title': "Jeffries swipes at House GOP's new Israel aid bill - Axios",
#    'description': None,
#    'url': 'https://www.axios.com/2024/02/04/house-israel-aid-hakeem-jeffries',
#    'urlToImage': None,
#    'publishedAt': '2024-02-04T15:18:28Z',
#    'content': None},
#   {'source': {'id': 'cbs-news', 'name': 'CBS News'},
#    'author': 'Kaia Hubbard',
#    'title': 'South Carolina Democratic primary turnout for 2024 and how it compares to previous years - CBS News',
#    'description': 'The showing marks the lowest turnout in the last few presidential primaries for Democrats. But the contest was far-less competitive.',
#    'url': 'https://www.cbsnews.com/news/south-carolina-democratic-primary-turnout-2024-joe-biden/',
#    'urlToImage': 'https://assets3.cbsnewsstatic.com/hub/i/r/2024/02/04/f4b538c1-b9d0-41f8-b2ab-f680dbffc80b/thumbnail/1200x630/3cf37e7fa089ad8527b940ea0f1414cd/gettyimages-1976106980.jpg?v=46393ce924f64f970b15aff36d86add7',
#    'publishedAt': '2024-02-04T14:20:05Z',
#    'content': "Washington — President Biden cruised to an easy victory Saturday in South Carolina's Democratic primary\xa0as the incumbent facing two long-shot candidates, winning about 96% of the vote with 97% of pre… [+2988 chars]"},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Kasha Patel',
#    'title': 'Scientists think our shrinking moon is causing concerning lunar quakes - The Washington Post',
#    'description': 'The moon’s shrinking has been measurable, but small. It has contracted about 150 feet in circumference over the last few hundred million years.',
#    'url': 'https://www.washingtonpost.com/climate-environment/2024/02/04/moon-shrinking-moonquakes-nasa/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/O6LITDK5IJLQI5OPRCRKFY3ROY_size-normalized.jpg&w=1440',
#    'publishedAt': '2024-02-04T13:38:14Z',
#    'content': 'For hundreds of millions of years, our moon has been shriveling like a raisin. Now, scientists say that decrease in circumference is leading to shallow moonquakes including near NASAs potential sites… [+6530 chars]'}]}

# %% [markdown]
# Easy enough. I think I'll grab the source name and the url for each post. Then I can format my tweets like this: Source - Headline. [Link]

# %%
for article in response.json()['articles']:

    print(article['source']['name'])

    print(article['url'])

    print()
# Out:
# Politico
# https://www.politico.com/news/2024/02/04/us-strikes-iran-jake-sullivan-00139490
#
# The Wall Street Journal
# https://www.wsj.com/tech/facebook-turns-20-from-mark-zuckerbergs-harvard-dorm-room-to-the-metaverse-817a73da
#
# USA Today
# https://www.usatoday.com/story/news/politics/2024/02/04/gov-noem-banned-from-south-dakota-reservation-following-border-remarks/72472410007/
#
# [Removed]
# https://removed.com
#
# The Hill
# https://thehill.com/homenews/state-watch/4447433-former-trump-official-dies-after-being-shot-in-dc-carjacking-spree/
#
# BBC News
# https://www.bbc.com/news/world-africa-68196412
#
# CNN
# https://www.cnn.com/2024/02/04/us/california-atmospheric-river-flooding/index.html
#
# The Times of Israel
# https://www.timesofisrael.com/after-ben-gvir-pans-biden-netanyahu-lauds-white-house-support-during-war/
#
# FRANCE 24 English
# https://www.france24.com/en/environment/20240204-air-pollution-factor-spiking-cancer-cases-who-says
#
# Deadline
# http://deadline.com/2024/02/snl-ayo-edebiri-seemingly-addresses-controversial-comments-about-jennifer-lopez-1235813828/
#
# Florida Today
# https://www.floridatoday.com/story/tech/science/space/2024/02/03/will-rain-wind-scuttle-nasa-pace-spacecraft-launch-tuesday-morning-at-cape-canaveral-florida/72449585007/
#
# Fox News
# https://www.foxnews.com/politics/trump-reveals-criteria-running-mate-name-drops-two-top-republicans
#
# Www.cnn.co
# https://www.cnn.co/interactive/2024/02/world/solar-eclipse-2024-map-dg-scn/
#
# Bleacher Report
# https://bleacherreport.com/articles/10107920-the-rock-thanks-cody-rhodes-amid-rumors-backlash-to-roman-reigns-wrestlemania-tease
#
# New York Post
# https://nypost.com/2024/02/04/sports/bill-belichick-thanks-patriots-fans-with-full-page-boston-globe-ad/
#
# Bleacher Report
# https://bleacherreport.com/articles/10107914-lakers-rumors-lal-have-not-reacted-to-lebron-james-maneuvers-about-trade-help
#
# Associated Press
# https://apnews.com/article/el-salvador-election-bukele-gang-violence-democracy-dc9f65f450875c5841f937753cd3101a
#
# Axios
# https://www.axios.com/2024/02/04/house-israel-aid-hakeem-jeffries
#
# CBS News
# https://www.cbsnews.com/news/south-carolina-democratic-primary-turnout-2024-joe-biden/
#
# The Washington Post
# https://www.washingtonpost.com/climate-environment/2024/02/04/moon-shrinking-moonquakes-nasa/

# %% [markdown]
# That was the easy part. The difficult part becomes reformatting my scripts to accomodate a new structure of data. I will use the JSON structure: each article will be its own dictionary in the list, containing the source, link, and headline information.
#
# I will re-format the existing function in this notebook to allow for the collection of this additional information.

# %%
def get_headlines(key=API_KEY):
    
    """Retrieves the latest breaking news headlines from the news api.
    
    Uses regex to remove the source from the end of the headline.
    
    Returns a list of headlines to be fed into ChatGPT for meme creation."""
    
    url = f"https://newsapi.org/v2/top-headlines?country=us&apiKey={key}"
    
    response = requests.get(url)
    
    articles = []
    
    regexp = r"^(.*?)\s\-\s.{0,25}$"
    
    for article in response.json()['articles']:
        
        try:
        
            title = re.search(regexp, article['title']).groups()[0]

            source = article['source']['name']

            link = article['url']

            info_dict = {'title': title, 'source': source, 'link': link}

            articles.append(info_dict)
            
        except:
            
            print('Article removed. Continuing.')
            
            continue
            
    print('All headlines retrieved! Moving on to descriptions..')        
        
    return articles

# %%
test_art = get_headlines()

test_art
# Out:
# Article removed. Continuing.
# All headlines retrieved! Moving on to descriptions..
# [{'title': 'US declines to rule out hitting targets in Iran, Jake Sullivan says',
#   'source': 'Politico',
#   'link': 'https://www.politico.com/news/2024/02/04/us-strikes-iran-jake-sullivan-00139490'},
#  {'title': "Facebook Turns 20: From Mark Zuckerberg's Harvard Dorm Room to the Metaverse",
#   'source': 'The Wall Street Journal',
#   'link': 'https://www.wsj.com/tech/facebook-turns-20-from-mark-zuckerbergs-harvard-dorm-room-to-the-metaverse-817a73da'},
#  {'title': 'South Dakota tribe banned Gov. Noem from reservation over comments on U.S.-Mexico border',
#   'source': 'USA Today',
#   'link': 'https://www.usatoday.com/story/news/politics/2024/02/04/gov-noem-banned-from-south-dakota-reservation-following-border-remarks/72472410007/'},
#  {'title': 'Former Trump official dies after being shot in DC carjacking spree',
#   'source': 'The Hill',
#   'link': 'https://thehill.com/homenews/state-watch/4447433-former-trump-official-dies-after-being-shot-in-dc-carjacking-spree/'},
#  {'title': "Hage Geingob death: Namibia's new President Mbumba sworn-in hours after predecessor dies",
#   'source': 'BBC News',
#   'link': 'https://www.bbc.com/news/world-africa-68196412'},
#  {'title': 'An intense atmospheric river moves into California, threatening to flood roads and trigger mudslides',
#   'source': 'CNN',
#   'link': 'https://www.cnn.com/2024/02/04/us/california-atmospheric-river-flooding/index.html'},
#  {'title': 'After Ben Gvir pans Biden, Netanyahu lauds White House support during war',
#   'source': 'The Times of Israel',
#   'link': 'https://www.timesofisrael.com/after-ben-gvir-pans-biden-netanyahu-lauds-white-house-support-during-war/'},
#  {'title': 'Air pollution a factor in spiking cancer cases, report says',
#   'source': 'FRANCE 24 English',
#   'link': 'https://www.france24.com/en/environment/20240204-air-pollution-factor-spiking-cancer-cases-who-says'},
#  {'title': '‘SNL’: Ayo Edebiri Seemingly Addresses Her Controversial Comments About Jennifer Lopez: ‘It’s Wrong to Run Your Mouth on a Podcast’',
#   'source': 'Deadline',
#   'link': 'http://deadline.com/2024/02/snl-ayo-edebiri-seemingly-addresses-controversial-comments-about-jennifer-lopez-1235813828/'},
#  {'title': 'Will rain, wind scuttle NASA PACE spacecraft launch Tuesday morning?',
#   'source': 'Florida Today',
#   'link': 'https://www.floridatoday.com/story/tech/science/space/2024/02/03/will-rain-wind-scuttle-nasa-pace-spacecraft-launch-tuesday-morning-at-cape-canaveral-florida/72449585007/'},
#  {'title': 'Trump reveals criteria for running mate, name drops two top Republicans',
#   'source': 'Fox News',
#   'link': 'https://www.foxnews.com/politics/trump-reveals-criteria-running-mate-name-drops-two-top-republicans'},
#  {'title': "Where to watch 2024's solar eclipse",
#   'source': 'Www.cnn.co',
#   'link': 'https://www.cnn.co/interactive/2024/02/world/solar-eclipse-2024-map-dg-scn/'},
#  {'title': 'The Rock Thanks Cody Rhodes amid Rumors, Backlash to Roman Reigns WrestleMania Tease',
#   'source': 'Bleacher Report',
#   'link': 'https://bleacherreport.com/articles/10107920-the-rock-thanks-cody-rhodes-amid-rumors-backlash-to-roman-reigns-wrestlemania-tease'},
#  {'title': 'Bill Belichick thanks Patriots fans with full-page Boston Globe ad',
#   'source': 'New York Post',
#   'link': 'https://nypost.com/2024/02/04/sports/bill-belichick-thanks-patriots-fans-with-full-page-boston-globe-ad/'},
#  {'title': "Lakers Rumors: LAL 'Have Not Reacted to' LeBron James' 'Maneuvers' About Trade Help",
#   'source': 'Bleacher Report',
#   'link': 'https://bleacherreport.com/articles/10107914-lakers-rumors-lal-have-not-reacted-to-lebron-james-maneuvers-about-trade-help'},
#  {'title': 'El Salvador election: Salvadorans head to vote as Bukele eyes second term',
#   'source': 'Associated Press',
#   'link': 'https://apnews.com/article/el-salvador-election-bukele-gang-violence-democracy-dc9f65f450875c5841f937753cd3101a'},
#  {'title': "Jeffries swipes at House GOP's new Israel aid bill",
#   'source': 'Axios',
#   'link': 'https://www.axios.com/2024/02/04/house-israel-aid-hakeem-jeffries'},
#  {'title': 'South Carolina Democratic primary turnout for 2024 and how it compares to previous years',
#   'source': 'CBS News',
#   'link': 'https://www.cbsnews.com/news/south-carolina-democratic-primary-turnout-2024-joe-biden/'},
#  {'title': 'Scientists think our shrinking moon is causing concerning lunar quakes',
#   'source': 'The Washington Post',
#   'link': 'https://www.washingtonpost.com/climate-environment/2024/02/04/moon-shrinking-moonquakes-nasa/'}]

# %% [markdown]
# Great success. This has cascading consequences in my existing pipeline. The function now returns a JSON object instead of a simple list. I need to alter my future functions in the pipeline to specifically access the title of each article. Looking at my pipeline, this affects the get_meme_desc function immediately and will require me to alter the two following scripts as well.

# %% [markdown]
# Let me test some string concatenation shenanigans to make sure I can properly edit the new tweets to contain the additional bits of information.

# %%
for art in test_art:

    print()

    hashtags = '#currentevents #breaking #memenews'

    full_string = f"{art['source']} | {art['title']} {hashtags}\n\n{art['link']}"

    print(full_string)

    print(len(full_string))
# Out:
# Politico | US declines to rule out hitting targets in Iran, Jake Sullivan says #currentevents #breaking #memenews
#
# https://www.politico.com/news/2024/02/04/us-strikes-iran-jake-sullivan-00139490
# 194
#
# The Wall Street Journal | Facebook Turns 20: From Mark Zuckerberg's Harvard Dorm Room to the Metaverse #currentevents #breaking #memenews
#
# https://www.wsj.com/tech/facebook-turns-20-from-mark-zuckerbergs-harvard-dorm-room-to-the-metaverse-817a73da
# 247
#
# USA Today | South Dakota tribe banned Gov. Noem from reservation over comments on U.S.-Mexico border #currentevents #breaking #memenews
#
# https://www.usatoday.com/story/news/politics/2024/02/04/gov-noem-banned-from-south-dakota-reservation-following-border-remarks/72472410007/
# 276
#
# The Hill | Former Trump official dies after being shot in DC carjacking spree #currentevents #breaking #memenews
#
# https://thehill.com/homenews/state-watch/4447433-former-trump-official-dies-after-being-shot-in-dc-carjacking-spree/
# 230
#
# BBC News | Hage Geingob death: Namibia's new President Mbumba sworn-in hours after predecessor dies #currentevents #breaking #memenews
#
# https://www.bbc.com/news/world-africa-68196412
# 182
#
# CNN | An intense atmospheric river moves into California, threatening to flood roads and trigger mudslides #currentevents #breaking #memenews
#
# https://www.cnn.com/2024/02/04/us/california-atmospheric-river-flooding/index.html
# 225
#
# The Times of Israel | After Ben Gvir pans Biden, Netanyahu lauds White House support during war #currentevents #breaking #memenews
#
# https://www.timesofisrael.com/after-ben-gvir-pans-biden-netanyahu-lauds-white-house-support-during-war/
# 235
#
# FRANCE 24 English | Air pollution a factor in spiking cancer cases, report says #currentevents #breaking #memenews
#
# https://www.france24.com/en/environment/20240204-air-pollution-factor-spiking-cancer-cases-who-says
# 215
#
# Deadline | ‘SNL’: Ayo Edebiri Seemingly Addresses Her Controversial Comments About Jennifer Lopez: ‘It’s Wrong to Run Your Mouth on a Podcast’ #currentevents #breaking #memenews
#
# http://deadline.com/2024/02/snl-ayo-edebiri-seemingly-addresses-controversial-comments-about-jennifer-lopez-1235813828/
# 298
#
# Florida Today | Will rain, wind scuttle NASA PACE spacecraft launch Tuesday morning? #currentevents #breaking #memenews
#
# https://www.floridatoday.com/story/tech/science/space/2024/02/03/will-rain-wind-scuttle-nasa-pace-spacecraft-launch-tuesday-morning-at-cape-canaveral-florida/72449585007/
# 291
#
# Fox News | Trump reveals criteria for running mate, name drops two top Republicans #currentevents #breaking #memenews
#
# https://www.foxnews.com/politics/trump-reveals-criteria-running-mate-name-drops-two-top-republicans
# 218
#
# Www.cnn.co | Where to watch 2024's solar eclipse #currentevents #breaking #memenews
#
# https://www.cnn.co/interactive/2024/02/world/solar-eclipse-2024-map-dg-scn/
# 160
#
# Bleacher Report | The Rock Thanks Cody Rhodes amid Rumors, Backlash to Roman Reigns WrestleMania Tease #currentevents #breaking #memenews
#
# https://bleacherreport.com/articles/10107920-the-rock-thanks-cody-rhodes-amid-rumors-backlash-to-roman-reigns-wrestlemania-tease
# 267
#
# New York Post | Bill Belichick thanks Patriots fans with full-page Boston Globe ad #currentevents #breaking #memenews
#
# https://nypost.com/2024/02/04/sports/bill-belichick-thanks-patriots-fans-with-full-page-boston-globe-ad/
# 223
#
# Bleacher Report | Lakers Rumors: LAL 'Have Not Reacted to' LeBron James' 'Maneuvers' About Trade Help #currentevents #breaking #memenews
#
# https://bleacherreport.com/articles/10107914-lakers-rumors-lal-have-not-reacted-to-lebron-james-maneuvers-about-trade-help
# 260
#
# Associated Press | El Salvador election: Salvadorans head to vote as Bukele eyes second term #currentevents #breaking #memenews
#
# https://apnews.com/article/el-salvador-election-bukele-gang-violence-democracy-dc9f65f450875c5841f937753cd3101a
# 240
#
# Axios | Jeffries swipes at House GOP's new Israel aid bill #currentevents #breaking #memenews
#
# https://www.axios.com/2024/02/04/house-israel-aid-hakeem-jeffries
# 160
#
# CBS News | South Carolina Democratic primary turnout for 2024 and how it compares to previous years #currentevents #breaking #memenews
#
# https://www.cbsnews.com/news/south-carolina-democratic-primary-turnout-2024-joe-biden/
# 222
#
# The Washington Post | Scientists think our shrinking moon is causing concerning lunar quakes #currentevents #breaking #memenews
#
# https://www.washingtonpost.com/climate-environment/2024/02/04/moon-shrinking-moonquakes-nasa/
# 222

# %% [markdown]
# This output is great. I've slightly altered it in the official script but this investigation allowed me to consider my options and format my tweets in a way I like.
